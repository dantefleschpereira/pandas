# %%
import pandas as pd

# %%
df = pd.read_csv('contracts.csv')
# Out:
# C:\Users\dante\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (2,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
display(df)
# Out:
#                                Purchase Order Description  \
# 0       DFSS-CORP-YS-CJI: CORP - YOUTH SERVICES - COMM...
# 1       DFSS-ECBG-CS-PISS: PREVENTION INITIATIVE SUPPO...
# 2       700819: INDUSTRIAL EQUIPMENT, TOOLS, ATTACHMEN...
# 3                                        LEASE / L-14121C
# 4       Grant Agreement, YOCM Documentary Grant, Urban...
# ...                                                   ...
# 139062                    EMS INCIDENT REPORT DATA SYSTEM
# 139063                          REPAIR, ASPHALT EMERGENCY
# 139064           MASTER AGREEMENT FOR DEMOLITION SERVICES
# 139065                                JANITORIAL SUPPLIES
# 139066                          STERLING MICROVISION FILM
#
#        Purchase Order (Contract) Number Revision Number Specification Number  \
# 0                                 77041               2               774638
# 1                                106913               1               466260
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139067 entries, 0 to 139066
# Data columns (total 19 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Purchase Order Description        136453 non-null  object
#  1   Purchase Order (Contract) Number  139067 non-null  object
#  2   Revision Number                   139067 non-null  object
#  3   Specification Number              126845 non-null  object
#  4   Contract Type                     94320 non-null   object
#  5   Start Date                        97788 non-null   object
#  6   End Date                          96680 non-null   object
#  7   Approval Date                     139046 non-null  object
#  8   Department                        129650 non-null  object
#  9   Vendor Name                       139067 non-null  object
#  10  Vendor ID                         139067 non-null  object
# ...

# %%
df.drop(columns=['Purchase Order Description'])
# Out:
#        Purchase Order (Contract) Number Revision Number Specification Number  \
# 0                                 77041               2               774638
# 1                                106913               1               466260
# 2                                117383               0               700819
# 3                                 30418              67               125804
# 4                                117399               0              1193898
# ...                                 ...             ...                  ...
# 139062                           T27465               0            B72051107
# 139063                           T25270               0            B69680704
# 139064                           F02424               0            B19683203
# 139065                           T27500               0            B74851001
# 139066                          S028945               0           S898020001
#
# ...

# %%
display(df)
# Out:
#                                Purchase Order Description  \
# 0       DFSS-CORP-YS-CJI: CORP - YOUTH SERVICES - COMM...
# 1       DFSS-ECBG-CS-PISS: PREVENTION INITIATIVE SUPPO...
# 2       700819: INDUSTRIAL EQUIPMENT, TOOLS, ATTACHMEN...
# 3                                        LEASE / L-14121C
# 4       Grant Agreement, YOCM Documentary Grant, Urban...
# ...                                                   ...
# 139062                    EMS INCIDENT REPORT DATA SYSTEM
# 139063                          REPAIR, ASPHALT EMERGENCY
# 139064           MASTER AGREEMENT FOR DEMOLITION SERVICES
# 139065                                JANITORIAL SUPPLIES
# 139066                          STERLING MICROVISION FILM
#
#        Purchase Order (Contract) Number Revision Number Specification Number  \
# 0                                 77041               2               774638
# 1                                106913               1               466260
# ...

# %%
df["Start Date"] = pd.to_datetime(df["Start Date"], errors = 'coerce')

# %%
df["End Date"] = pd.to_datetime(df["End Date"], errors = 'coerce')

# %%
df['End Date'] = df['End Date'].dt.strftime('%d/%m/%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139067 entries, 0 to 139066
# Data columns (total 19 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Purchase Order Description        136453 non-null  object
#  1   Purchase Order (Contract) Number  139067 non-null  object
#  2   Revision Number                   139067 non-null  object
#  3   Specification Number              126845 non-null  object
#  4   Contract Type                     94320 non-null   object
#  5   Start Date                        97784 non-null   datetime64[ns]
#  6   End Date                          96680 non-null   object
#  7   Approval Date                     139046 non-null  object
#  8   Department                        129650 non-null  object
#  9   Vendor Name                       139067 non-null  object
#  10  Vendor ID                         139067 non-null  object
# ...

# %%
display(df)
# Out:
#                                Purchase Order Description  \
# 0       DFSS-CORP-YS-CJI: CORP - YOUTH SERVICES - COMM...
# 1       DFSS-ECBG-CS-PISS: PREVENTION INITIATIVE SUPPO...
# 2       700819: INDUSTRIAL EQUIPMENT, TOOLS, ATTACHMEN...
# 3                                        LEASE / L-14121C
# 4       Grant Agreement, YOCM Documentary Grant, Urban...
# ...                                                   ...
# 139062                    EMS INCIDENT REPORT DATA SYSTEM
# 139063                          REPAIR, ASPHALT EMERGENCY
# 139064           MASTER AGREEMENT FOR DEMOLITION SERVICES
# 139065                                JANITORIAL SUPPLIES
# 139066                          STERLING MICROVISION FILM
#
#        Purchase Order (Contract) Number Revision Number Specification Number  \
# 0                                 77041               2               774638
# 1                                106913               1               466260
# ...
